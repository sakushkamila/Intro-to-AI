# %% [markdown]
# ![KBTU_logo.png](attachment:KBTU_logo.png)
# ### Introduction to Artificial Intelligence
# Instructor: Zhalgas Zhiyenbekov,
# z.zhiyenbekov@kbtu.kz

# %% [markdown]
# ### Project 2 [House price]
#
# - soft deadline 08.12.2023 23.59
# - hard deadline 10.12.2023 23.59 (-2 scores)

# %% [markdown]
# You are given a dataset containing information about houses and **prices**. The dataset is already split into ```train.csv``` and ```test.csv```. The file ```data_description.txt``` contains descriptions of the columns.
#
# **Goal:** build models to predict house prices.
#
# Please include detailed explanations of the following steps:
#
# 1. Cleaning, pre-processing of data
#
# 2. Training and testing models.
#
# 3. Comparison of models based on regression metrics.
#
# **Note:** You are **encouraged** to search for other machine learning algorithms online (not limited to the course material), but you must study and understand these algorithms. You cannot delete any line in the test.csv file.
#
#
# Instruction to do the project:
# - Please, do your analyses and model in this notebook. Do not create the module (.py)
# - Save your file with the correct form <familyname_name_sis2.ipynb>
# - Compress all files used in the project as ZIP and send me the .zip file in the format <familyname_name_sis2.zip>
# - Zip file should contain all files!
# - File should be sent to the email z_zhiyenbekov@kbtu.kz. Please, put a copy to z.zhiyenbekov@kbtu.kz
# - Do not forget to title the email SIS3-Final_Project
#
# **!!! In case of unappropriate format of file -2 scores**
